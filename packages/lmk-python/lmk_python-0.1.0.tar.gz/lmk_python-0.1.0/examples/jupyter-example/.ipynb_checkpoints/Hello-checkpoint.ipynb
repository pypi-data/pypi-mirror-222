# %%
import lmk
import threading
import time
import IPython

# %%
lmk.jupyter.set_log_level("DEBUG")

# %%
lmk.jupyter
# Out:
# LMKWidget(access_token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0eXBlIjoiYWNjZXNzX3Rva2VuIiwic2NvcGUiOiJldmVud…

# %%
stdout = lmk.jupyter.get_widget().thread.stdout

# %%
IPython.get_ipython().kernel.saved_sigint_handler
# Out:
# <Handlers.SIG_IGN: 1>

# %%
help(IPython.get_ipython().kernel)
# Out:
# Help on IPythonKernel in module ipykernel.ipkernel object:
#
# class IPythonKernel(ipykernel.kernelbase.Kernel)
#  |  IPythonKernel(**kwargs)
#  |
#  |  The IPython Kernel class.
#  |
#  |  Method resolution order:
#  |      IPythonKernel
#  |      ipykernel.kernelbase.Kernel
#  |      traitlets.config.configurable.SingletonConfigurable
#  |      traitlets.config.configurable.LoggingConfigurable
#  |      traitlets.config.configurable.Configurable
#  |      traitlets.traitlets.HasTraits
#  |      traitlets.traitlets.HasDescriptors
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, **kwargs)
#  |      Initialize the kernel.
#  |
#  |  dispatch_debugpy(self, msg)
#  |
#  |  do_apply(self, content, bufs, msg_id, reply_metadata)
#  |      Handle an apply request.
#  |
#  |  do_clear(self)
#  |      Clear the kernel.
#  |
#  |  do_complete(self, code, cursor_pos)
#  |      Handle code completion.
#  |
#  |  async do_debug_request(self, msg)
# ...

# %%
print(stdout.getvalue())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(stdout.getvalue())
#
# NameError: name 'stdout' is not defined

# %%
from datetime import datetime
print("START", datetime.utcnow().isoformat())
try:
    for _ in range(100):
        time.sleep(1)
finally:
    print("END", datetime.utcnow().isoformat())
# Out:
# START 2023-07-18T02:11:48.786279
# END 2023-07-18T02:11:57.919516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 try:
#       4     for _ in range(100):
# ----> 5         time.sleep(1)
#       6 finally:
#       7     print("END", datetime.utcnow().isoformat())
#
# KeyboardInterrupt:

# %%
w = lmk.jupyter.get_widget()

# %%
help(w.comm.observe)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 help(w.comm.observe)
#
# AttributeError: 'BaseComm' object has no attribute 'observe'

# %%
dir(w.comm)
# Out:
# ['__annotations__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_close_callback',
#  '_close_data',
#  '_closed',
#  '_msg_callback',
#  '_open_data',
#  'close',
#  'comm_id',
#  'handle_close',
#  'handle_msg',
#  'kernel',
#  'on_close',
#  'on_msg',
#  'open',
#  'primary',
#  'publish_msg',
#  'send',
#  'target_module',
#  'target_name',
#  'topic']

# %%
help(w.comm.on_msg)
# Out:
# Help on method on_msg in module comm.base_comm:
#
# on_msg(callback) method of ipykernel.comm.comm.BaseComm instance
#     Register a callback for comm_msg
#
#     Will be called with the `data` of any comm_msg messages.
#
#     Call `on_msg(None)` to disable an existing callback.

# %%
w.comm._msg_callback
# Out:
# <bound method _show_traceback.<locals>.m of LMKWidget()>

# %%
w.comm
